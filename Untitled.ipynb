# %%
import tensorflow as tf

# %%
import sys

# %%
sys.version
# Out:
# '3.9.12 (main, Mar 24 2022, 16:21:12) \n[GCC 7.5.0]'

# %%
tf.keras.Sequential
# Out:
# keras.engine.sequential.Sequential

# %%
# !pip3 install manim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached manim-0.15.1-py3-none-any.whl (523 kB)
# ...
#   Using cached moderngl_window-2.4.1-py3-none-any.whl (365 kB)
# ...
#   Using cached pycairo-1.21.0.tar.gz (340 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached screeninfo-0.8-py3-none-any.whl (14 kB)
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached mapbox_earcut-0.12.11-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (98 kB)
# ...
#   Using cached isosurfaces-0.1.0-py3-none-any.whl (10 kB)
# ...
#   Using cached watchdog-2.1.7-py3-none-manylinux2014_x86_64.whl (76 kB)
# ...
#   Using cached ManimPango-0.4.1.tar.gz (4.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached click-8.1.2-py3-none-any.whl (96 kB)
# ...

# %%
from manim import *
# Out:
# Manim Community v0.15.1
